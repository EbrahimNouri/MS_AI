# %% [markdown]
# # 1

# %%
def calculate_regression(x_name, y_name):
  X = df[[x_name]]
  y = df[y_name]

  # display(X.head())
  # display(df.head())

  x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

  model = LinearRegression()
  model.fit(x_train, y_train)
  y_pred = model.predict(x_test)

  print("Feature: ", x_name)
  print("Target: ", y_name)
  print("Coefficients: ", model.coef_)
  print("Intercept: ", model.intercept_)
  print("R2 : ", model.score(x_test, y_test))

  plt.scatter(x_test, y_test, color="blue", alpha=0.4, label="Actual Test Data")
  plt.plot(x_test, y_pred, color="red", linewidth=2, label="Linear Regression Line")
  plt.xlabel("Median Income (MedInc)")
  plt.ylabel("Median House Value (MedHouseVal)")
  plt.title(f"California Housing: {x_name} vs House Value")
  plt.legend()
  plt.show()

# %%
from sklearn.datasets import fetch_california_housing
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing
from sklearn.linear_model import LinearRegression

housing = fetch_california_housing(as_frame=True)
df = housing.frame

# %% [markdown]
# پارامتر as_frame=True داده‌ها را به جای آرایه‌های خام پایتون (NumPy)، در قالب جدول‌های Pandas (یعنی DataFrame و Series) بارگذاری می‌کند.این کار باعث می‌شود نام ستون‌ها (مثل سن خانه یا میزان درآمد) حفظ شود و تحلیل و تغییر داده‌ها بسیار ساده‌تر باشد.

# %%
calculate_regression("MedInc", "MedHouseVal")
calculate_regression("AveRooms", "MedHouseVal")
calculate_regression("HouseAge", "MedHouseVal")
# Out:
# Feature:  MedInc
# Target:  MedHouseVal
# Coefficients:  [0.41819327]
# Intercept:  0.44794965556043254
# R2 :  0.47293192589970245
# Feature:  AveRooms
# Target:  MedHouseVal
# Coefficients:  [0.07175754]
# Intercept:  1.679013149730682
# R2 :  0.022958759121733507
# Feature:  HouseAge
# Target:  MedHouseVal
# Coefficients:  [0.00977751]
# Intercept:  1.7898435480386743
# R2 :  0.010677917913109347

# %% [markdown]
# # 2

# %%
X = df[["MedInc", "HouseAge", "AveRooms"]]
y = df["MedHouseVal"]

# display(X.head())
# display(df.head())

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model_lr = LinearRegression()
model_lr.fit(X_train, y_train)
y_pred = model_lr.predict(X_test)

print("Coefficients: ", model_lr.coef_)
print("Intercept: ", model_lr.intercept_)
print("R2 : ", model_lr.score(X_test, y_test))
# Out:
# Coefficients:  [ 0.44191756  0.01683785 -0.02551413]
# Intercept:  0.013574378569972012
# R2 :  0.5126516784926669
